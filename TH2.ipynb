# %%
print("HELLO WORLD!")

# %%
a= input()
print("hello a")

# %%
a,b=map(int,input().split())

# %%
a1,b1.c1,a2,b2,a3=map(int,input()split())
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(round(TB,1))

# %%
a,b=map(int,input().split())
print(a**b)

# %%
a=input()
print(ord(a))
a=a.upper()
print(a)

# %%
A=((13**2)*3)+5
B= 13**2*3+5
print(A)
print(B)

# %%
C=int(input())
print(round(F,2))

# %%
x=float(input("nhap gia dong ho"))
shipping=10
tax_export=0.30*x
tax_vat=0.10*x
total=x+shipping+tax_export+tax_vat
print(round(total,2))

# %%
A=input("nhap ten ba nguoi").split()
A.reverse()
output=f"{A[0]},{A[1]} and {A[2]}"
print(f"({output})")

# %%
h=int(input())
m=int(input())
total_seconds=h*3600+m*60
print(total_seconds)

# %%
a=int(input())
stickers=6*(a*a)
print(stickers)

# %%
a=int(input())
b=int(input())
S=a*b
print=(S)

# %%
a=int(input("nhap a:"))
b-int(input("nhap b:"))
a,b=b,a
print("a=",a)
print("b=",b)

# %%
n=int(input())
S=6*n*(n-1)+1
print(S)

# %%
print("Spring")
print("Summer")
print("Autumn")
print("Winter")

# %%
print("*")
print("***")
print("*****")

# %%
print("### # #   ### ###")
print(" #  #   #  #   # ")
print(" #  #    # #   # ")
print(" #  #   #  #   # ")
print(" #  # #    #   # ")

# %%
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")

# %%
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")

# %%
diem=float(input("nhap diem cua ban:"))
if diem>=8.0:
    print("hoc luc gioi")
elif 6.5<=diem:
    print("hoc luc kha")
elif 5.0<=diem:
    print("hoc luc trung binh")
else:
    print("hoc luc yeu")
