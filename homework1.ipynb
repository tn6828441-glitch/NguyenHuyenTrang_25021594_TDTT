# %%
Bài1:
n=int(input())
print(2*n)

# %%
Bài2:
a=float(input())
b=float(input())
pi=3.14
r=a/2
s=a*b-pi*r*r
print(round(s,2))

# %%
Bài3:
c=input()
if c.isupper():
    print(c.lower())
else:
    print(c.upper())

# %%
Bài4:
c=input()
if c.isalpha():
    print(f"{c} la ki tu alphabet")
else:
    print(f"{c} khong phai la ki hieu alphabet")

# %%
Bài6:
a=float(input())
b=float(input())
c=float(input())
if a+b>c and a+c>b and b+c>a:
    p=(a+b+c/2)
    print(round(p*(p-a)*(p-b)*(p-c)).1)
else:
    print("khong phai 3 canh tam giac")
